# %% [markdown]
# <a href="https://colab.research.google.com/github/aneal191/Data110/blob/main/Week_2_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Anscombe's Quartet:
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %%
plt.scatter(x, y1)

# %%
# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y1, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y1)
plt.plot(x, regression_line,color='red')
plt.xlabel('x')
plt.ylabel('y1')
# Out:
# Text(0, 0.5, 'y1')

# %%
# My Code needs to be here for x and y2

# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y2, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y2)
plt.plot(x, regression_line,color='green')
plt.xlabel('x')
plt.ylabel('y2')
# Out:
# Text(0, 0.5, 'y2')

# %%
# MY Code need to be here for x and y3

# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y3, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y3)
plt.plot(x, regression_line,color='purple')
plt.xlabel('x')
plt.ylabel('y3')
# Out:
# Text(0, 0.5, 'y3')

# %%
# MY code need to be here for x and y4

# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y4, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y4)
plt.plot(x, regression_line,color='silver')
plt.xlabel('x')
plt.ylabel('y4')
# Out:
# Text(0, 0.5, 'y4')

# %%
# Your code need to be here for x4 and y4

# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x4, y4, 1)

# Create the regression line
regression_line = m * np.array(x4) + b

# Plot the data points and regression line
plt.scatter(x4, y4)
plt.plot(x4, regression_line,color='yellow')
plt.xlabel('x4')
plt.ylabel('y4')
# Out:
# Text(0, 0.5, 'y4')

# %% [markdown]
# Discuss any differences you observe when comparing the results across all datasets.
#
# Observations: The regression line is changing color. Also the dots are moving based on the datasets used. The labels also changed names based on the values entered in the python code.

# %% [markdown]
# Reflection Question:
# After visualizing the linear regression for all four datasets in Anscombe's Quartet, reflect on the following:
#
# What is your reflection?
# How do the datasets visually differ despite having similar summary statistics?
# # Some datasets have tighter or looser plots (dots scattered farther apart). The regression rises or falls or changes direction accordingly.
#
# How did the outlier in the x4, y4 dataset affect the regression line compared to the other datasets?
# # I think the slope changed as well as the y-intercept. Instead of being a vertical line on the x axis, there's a sloping line.
#
# Why is it important to visualize data in addition to calculating summary statistics?
# # I think it makes it easier to understand if you can visualize the data. It helps you understand the relationship between the variables.
#
# Please provide your insights and discuss the importance of data visualization in understanding relationships between variables.
# # It's just a better way at looking at data if you can visualize it, change colors, adjust labels, etc. Thanks. Fun exercise!
