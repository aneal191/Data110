# %% [markdown]
# <a href="https://colab.research.google.com/github/aneal191/Data110/blob/main/Week2_python_in_class_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]

# %%
type(x)
# Out:
# list

# %%
type(1)
# Out:
# int

# %%
min(x)
# Out:
# 4

# %%
plt.scatter(x,y1)

# %%
#  this is for comment
# lets create the regression line...y=mx+b where m is slope while b is y-intercept
m,b=np.polyfit(x,y1,1)
# lets first make x as np.array so we can do extra operation on it
x=np.array(x)
regression_line=m*x+b
plt.plot(x,regression_line)
plt.scatter(x,y1,color='orange',s=100)
plt.plot(x,regression_line,color='black')

# %%
plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
plt.scatter(x,2*x)
